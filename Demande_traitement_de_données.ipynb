# %% [markdown]
# <h1><center>  Analyse des dossiers passant de A01,A02 à A04 <h1><center>

# %% [markdown]
# ## I. Import Librairies

# %%
import pandas as pd
import numpy as np
from datetime import date

# %%
#pip install datetime

# %%
#f = pd.read_csv('/content/demande.csv',encoding='ISO-8859-1',sep=';')

# %% [markdown]
# # II. Import Data

# %%
df = pd.read_excel('/content/Classeur1.xlsx',sheet_name=1)

# %%
df = df.loc[(df['Type acte']=="A01") | (df['Type acte'] == "A04"),:]

# %% [markdown]
# #Dimension du jeu de données

# %%
df.shape
# Out:
# (580, 109)

# %% [markdown]
# # II. Code

# %%
df['Date acte'] = pd.to_datetime(df['Date acte'], format="%d/%m/%Y")

# %%
df2 = df

# %%
df3 = df2[df2.duplicated(subset=['Nom demandeur'], keep=False)]

# %%
df4 = (df3[['Nom demandeur','Type acte','Date acte','Prenom demandeur']])

# %%
df6 = df4.sort_values(by = ['Nom demandeur', 'Type acte'])

# %%
df6
# Out:
#     Nom demandeur Type acte  Date acte Prenom demandeur
# 116        ADJADJ       A01 2022-01-20            Sarah
# 117        ADJADJ       A01 2022-01-20            Sarah
# 489        ALIOUA       A01 2022-02-28           Hacina
# 721        ALIOUA       A01 2022-03-22           Hacina
# 622      ANQUETIL       A01 2022-03-14             Hugo
# ..            ...       ...        ...              ...
# 713         Saint       A04 2022-03-20           Renaud
# 552      TAILLEUR       A01 2022-03-04             Yann
# 775      TAILLEUR       A01 2022-03-25             Yann
# 77         WATTEL       A01 2022-01-14           Michel
# 528        WATTEL       A04 2022-03-02           Michel
#
# [110 rows x 4 columns]

# %%
df6= df6.drop_duplicates(subset=['Nom demandeur','Type acte','Prenom demandeur'], keep='first')

# %%
df6
# Out:
#     Nom demandeur Type acte  Date acte Prenom demandeur
# 116        ADJADJ       A01 2022-01-20            Sarah
# 489        ALIOUA       A01 2022-02-28           Hacina
# 622      ANQUETIL       A01 2022-03-14             Hugo
# 442      ANQUETIL       A04 2022-02-15           Thomas
# 252         AUGER       A01 2022-02-07            Jimmy
# ..            ...       ...        ...              ...
# 462         Saint       A01 2022-02-25           Renaud
# 713         Saint       A04 2022-03-20           Renaud
# 552      TAILLEUR       A01 2022-03-04             Yann
# 77         WATTEL       A01 2022-01-14           Michel
# 528        WATTEL       A04 2022-03-02           Michel
#
# [90 rows x 4 columns]

# %%
df6 = df6.reset_index(drop=True)

# %%
#len(df3.loc[(df3['Type acte']=="A01") | (df3['Type acte'] == "A02"),:])

# %%
from datetime import date
 
def numOfDays(date1, date2):
    return (date2-date1).days

# %%
def add_col_chauff_2012(dataset):
    dataset["New_Duree_acte"] = ""
    for i in range(len(dataset)):
        if dataset["Nom demandeur"][i] == dataset["Nom demandeur"].shift()[i] and dataset["Prenom demandeur"][i] == dataset["Prenom demandeur"].shift()[i]:
          #print(numOfDays(dataset['Date acte'].shift()[i], dataset['Date acte'][i]))
           dataset["New_Duree_acte"][i] = numOfDays(dataset['Date acte'].shift()[i], dataset['Date acte'][i])

# %%
add_col_chauff_2012(df6)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df6
# Out:
#    Nom demandeur Type acte  Date acte Prenom demandeur New_Duree_acte
# 0         ADJADJ       A01 2022-01-20            Sarah
# 1         ALIOUA       A01 2022-02-28           Hacina
# 2       ANQUETIL       A01 2022-03-14             Hugo
# 3       ANQUETIL       A04 2022-02-15           Thomas
# 4          AUGER       A01 2022-02-07            Jimmy
# ..           ...       ...        ...              ...            ...
# 85         Saint       A01 2022-02-25           Renaud
# 86         Saint       A04 2022-03-20           Renaud             23
# 87      TAILLEUR       A01 2022-03-04             Yann
# 88        WATTEL       A01 2022-01-14           Michel
# 89        WATTEL       A04 2022-03-02           Michel             47
#
# [90 rows x 5 columns]

# %%
df10 = (df6.loc[df6['Type acte']=="A01",:])

# %%
df10
# Out:
#    Nom demandeur Type acte  Date acte Prenom demandeur New_Duree_acte
# 0         ADJADJ       A01 2022-01-20            Sarah
# 1         ALIOUA       A01 2022-02-28           Hacina
# 2       ANQUETIL       A01 2022-03-14             Hugo
# 4          AUGER       A01 2022-02-07            Jimmy
# 5          AUGER       A01 2022-02-25          Grégory
# ..           ...       ...        ...              ...            ...
# 83       ROUSSEL       A01 2022-02-03           Sophie
# 84       ROUSSEL       A01 2022-02-14            ALAIN
# 85         Saint       A01 2022-02-25           Renaud
# 87      TAILLEUR       A01 2022-03-04             Yann
# 88        WATTEL       A01 2022-01-14           Michel
#
# [73 rows x 5 columns]

# %%
df11 = (df6.loc[df6['Type acte']=="A04",:])

# %%
df20 = pd.merge(df10,df11, how="inner", on=["Nom demandeur", "Prenom demandeur"])

# %%
df20
# Out:
#    Nom demandeur Type acte_x Date acte_x Prenom demandeur New_Duree_acte_x  \
# 0        BOUCHER         A01  2022-01-06          Romaric
# 1         CELLE          A01  2022-02-22          Michèle
# 2      CRAMOISAN         A01  2022-01-26         Dorothée
# 3       DIADHIOU         A01  2022-02-17           FAMARA
# 4          FEENY         A01  2022-01-04           Corine
# 5        GUERARD         A01  2022-01-20           Manuel
# 6    LECHEVALIER         A01  2022-01-06           Jeanne
# 7      LECOSSOIS         A01  2022-01-21          Bernard
# 8           MORO         A01  2022-01-13        Christine
# 9       PAVILLON         A01  2022-01-03          Vincent
# 10         Saint         A01  2022-02-25           Renaud
# 11        WATTEL         A01  2022-01-14           Michel
#
#    Type acte_y Date acte_y New_Duree_acte_y
# 0          A04  2022-03-04               57
# 1          A04  2022-03-18               24
# 2          A04  2022-02-10               15
# 3          A04  2022-03-21               32
# 4          A04  2022-03-07               62
# 5          A04  2022-03-03               42
# 6          A04  2022-03-09               62
# 7          A04  2022-03-18               56
# 8          A04  2022-02-22               40
# 9          A04  2022-02-17               45
# 10         A04  2022-03-20               23
# 11         A04  2022-03-02               47

# %%
df = pd.read_excel('/content/Classeur1.xlsx',sheet_name=1)

# %%
df12 = df.loc[(df['Type acte']=="A02"),:]

# %%
df12.shape
# Out:
# (259, 109)

# %%
df12 = (df12[['Nom demandeur','Type acte','Date acte','Prenom demandeur']])

# %%
#df13 = df10.merge(df12, left_on='Nom demandeur', right_on='Nom demandeur')

# %%
df21 = pd.merge(df20,df12, how="inner", on=["Nom demandeur", "Prenom demandeur"])

# %%
df21
# Out:
#   Nom demandeur Type acte_x Date acte_x Prenom demandeur New_Duree_acte_x  \
# 0       BOUCHER         A01  2022-01-06          Romaric
# 1        CELLE          A01  2022-02-22          Michèle
# 2     CRAMOISAN         A01  2022-01-26         Dorothée
# 3      DIADHIOU         A01  2022-02-17           FAMARA
# 4         FEENY         A01  2022-01-04           Corine
# 5       GUERARD         A01  2022-01-20           Manuel
# 6   LECHEVALIER         A01  2022-01-06           Jeanne
# 7          MORO         A01  2022-01-13        Christine
# 8      PAVILLON         A01  2022-01-03          Vincent
# 9        WATTEL         A01  2022-01-14           Michel
#
#   Type acte_y Date acte_y New_Duree_acte_y Type acte  Date acte
# 0         A04  2022-03-04               57       A02 2022-01-18
# 1         A04  2022-03-18               24       A02 2022-03-08
# 2         A04  2022-02-10               15       A02 2022-02-14
# 3         A04  2022-03-21               32       A02 2022-03-01
# 4         A04  2022-03-07               62       A02 2022-01-07
# 5         A04  2022-03-03               42       A02 2022-01-28
# 6         A04  2022-03-09               62       A02 2022-01-27
# 7         A04  2022-02-22               40       A02 2022-01-21
# 8         A04  2022-02-17               45       A02 2022-01-13
# 9         A04  2022-03-02               47       A02 2022-02-08

# %%
ds = []
for i in range(len(df21)):
  
  a = numOfDays(df21['Date acte'][i], df21['Date acte_y'][i])
  ds.append(a)
df21['Conso_ELS_mens_2012'] = ds

# %%
df21
# Out:
#   Nom demandeur Type acte_x Date acte_x Prenom demandeur New_Duree_acte_x  \
# 0       BOUCHER         A01  2022-01-06          Romaric
# 1        CELLE          A01  2022-02-22          Michèle
# 2     CRAMOISAN         A01  2022-01-26         Dorothée
# 3      DIADHIOU         A01  2022-02-17           FAMARA
# 4         FEENY         A01  2022-01-04           Corine
# 5       GUERARD         A01  2022-01-20           Manuel
# 6   LECHEVALIER         A01  2022-01-06           Jeanne
# 7          MORO         A01  2022-01-13        Christine
# 8      PAVILLON         A01  2022-01-03          Vincent
# 9        WATTEL         A01  2022-01-14           Michel
#
#   Type acte_y Date acte_y New_Duree_acte_y Type acte  Date acte  \
# 0         A04  2022-03-04               57       A02 2022-01-18
# 1         A04  2022-03-18               24       A02 2022-03-08
# 2         A04  2022-02-10               15       A02 2022-02-14
# 3         A04  2022-03-21               32       A02 2022-03-01
# 4         A04  2022-03-07               62       A02 2022-01-07
# 5         A04  2022-03-03               42       A02 2022-01-28
# 6         A04  2022-03-09               62       A02 2022-01-27
# 7         A04  2022-02-22               40       A02 2022-01-21
# 8         A04  2022-02-17               45       A02 2022-01-13
# 9         A04  2022-03-02               47       A02 2022-02-08
#
#    Conso_ELS_mens_2012
# 0                   45
# 1                   10
# 2                   -4
# 3                   20
# 4                   59
# 5                   34
# 6                   41
# 7                   32
# 8                   35
# 9                   22

# %%
df20.to_excel(r'resultat.xlsx', index = False)

# %%
df21.to_excel(r'resultat1.xlsx', index = False)

# %%
#df = df9

# %%
#df = df.reset_index(drop=True)

# %%
#from matplotlib import pyplot as plt

# %%
#import seaborn as sns

# %%
'''plt.figure(figsize=(10,6))
sns.barplot(x=df['Nom demandeur'], y=df['New_Duree_acte'], palette="Reds_r")
plt.xlabel('\nNom demandeur', fontsize=15, color='#c0392b')
plt.ylabel("Nombre de jour\n", fontsize=15, color='#c0392b')
plt.title("Nombre de jour entre l'acte 101 et l'acte A04 par personne\n", fontsize=18, color='#e74c3c')
plt.xticks(rotation= 45)
plt.tight_layout()'''
# Out:
# 'plt.figure(figsize=(10,6))\nsns.barplot(x=df[\'Nom demandeur\'], y=df[\'New_Duree_acte\'], palette="Reds_r")\nplt.xlabel(\'\nNom demandeur\', fontsize=15, color=\'#c0392b\')\nplt.ylabel("Nombre de jour\n", fontsize=15, color=\'#c0392b\')\nplt.title("Nombre de jour entre l\'acte 101 et l\'acte A04 par personne\n", fontsize=18, color=\'#e74c3c\')\nplt.xticks(rotation= 45)\nplt.tight_layout()'

# %%
'''import plotly.express as px

fig = px.pie(df9, values='New_Duree_acte', names='Nom demandeur')
fig.show()'''
# Out:
# "import plotly.express as px\n\nfig = px.pie(df9, values='New_Duree_acte', names='Nom demandeur')\nfig.show()"
